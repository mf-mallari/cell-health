# %% [markdown]
# # Apply Cell Health Models to Repurposing Set
#
# **Gregory Way, 2019**
#
# The models are trained to predict cell health phenotypes.
# Here, I apply the models to Cell Painting data from the repurposing set.
#
# I will use these predictions to identify compound perturbation signatures of cell health impact.

# %%
import os
import sys
import numpy as np
import pandas as pd
import scipy.stats
from joblib import load
import umap

from pycytominer import feature_select
from pycytominer.cyto_utils import infer_cp_features

sys.path.append("../3.train")
from scripts.ml_utils import load_train_test, load_models

# %%
np.random.seed(123)

# %% [markdown]
# ## 1) Load Models and Training Data

# %%
consensus = "modz"
output_dir = "data"

# %%
model_dir = os.path.join("..", "3.train", "models")

model_dict, model_coef = load_models(
    model_dir=model_dir,
    consensus=consensus
)
# Out:
# /opt/anaconda3/envs/cell-health/lib/python3.12/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator ElasticNet from version 1.2.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
data_dir = os.path.join("..", "3.train", "data")

x_train_df, x_test_df, y_train_df, y_test_df = load_train_test(
    data_dir=data_dir,
    consensus=consensus,
    drop_metadata=True
)

# %% [markdown]
# ## 2) Load Cell Painting Repurposing Data Files
#
# These files are available from https://github.com/broadinstitute/lincs-cell-painting

# %%
batch = "2016_04_01_a549_48hr_batch1"
commit_hash = "27a2d7dd74067b5754c2c045e9b1a9cfb0581ae4"

# We have noticed particular technical issues with this platemap
# remove it from downstream consideration
# https://github.com/broadinstitute/lincs-cell-painting/issues/43
filter_platemap = "C-7161-01-LM6-011"

# %%
# Load transformed data for testing (fixes feature mismatch)
transformed_file = "data/repurposing_transformed_features_fixed.tsv.gz"
if os.path.exists(transformed_file):
    print(f"Using transformed data for testing: {transformed_file}")
    complete_consensus_df = pd.read_csv(transformed_file, sep='\t')
    print(f"  - Shape: {complete_consensus_df.shape}")
    print(f"  - Features: {len([c for c in complete_consensus_df.columns if not c.startswith('Metadata_')])}")
else:
    print("ERROR: Transformed data not found for testing!")
    print("Please run: python transform_features.py")
    raise FileNotFoundError("Test data not available")
# Out:
# (10752, 1788)
#   Metadata_Plate_Map_Name   Metadata_broad_sample Metadata_pert_well  \
# 0       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B13
# 1       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B14
# 2       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B15
# 3       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B16
# 4       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B17
#
#    Metadata_mmoles_per_liter  Metadata_dose_recode  Cells_AreaShape_Area  \
# 0                   10.00000                     6              0.590843
# 1                    3.33330                     5              0.953997
# 2                    1.11110                     4              1.100220
# 3                    0.37037                     3              0.616491
# 4                    0.12346                     2              1.145410
#
#    Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                 -0.291888                  0.197000
# 1                  0.615666                 -0.003971
# 2                 -1.006300                 -0.324214
# 3                  0.523367                  0.723404
# 4                  1.452660                 -0.052850
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  ...  \
# 0                     0.025410                     -0.314847  ...
# 1                     0.362362                     -0.299340  ...
# 2                    -0.220141                     -0.572329  ...
# 3                     0.135139                      0.079898  ...
# 4                     0.194700                     -0.196077  ...
#
#    Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                        -0.856111                        -1.067810
# 1                        -0.197888                        -0.884445
# 2                        -0.251770                        -0.775027
# 3                        -0.692809                        -0.733101
# 4                        -0.417982                        -0.126697
#
#    Nuclei_Texture_Variance_ER_20_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                        -0.953925                       -1.126250
# 1                        -0.676961                       -0.979640
# 2                        -1.139090                       -0.699553
# 3                        -0.650335                       -0.942234
# 4                         0.261282                       -0.116643
#
#    Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_20_0  \
# 0                          -0.539351                          -0.413102
# 1                          -0.900894                          -0.897170
# 2                          -0.785571                          -0.801577
# 3                          -0.244557                          -0.182373
# 4                          -0.358850                          -0.438067
#
#    Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                         -0.587832                          0.822261
# 1                         -0.787205                         -0.673075
# 2                         -0.534207                         -0.420019
# 3                         -0.290681                         -0.470494
# 4                         -0.292326                         -0.400007
#
#    Nuclei_Texture_Variance_RNA_20_0  Nuclei_Texture_Variance_RNA_5_0
# 0                          0.738317                         0.878220
# 1                         -0.747765                        -0.346591
# 2                         -0.706492                        -0.202666
# 3                         -0.799699                        -0.323079
# 4                         -0.667327                        -0.206596
#
# [5 rows x 1788 columns]

# %%
# Apply feature selection to the consensus profiles (compatible with transformed data)
feature_ops = [
    "variance_threshold",
    "drop_na_columns",
    "blocklist",
    "drop_outliers"
]

consensus_feature_select_df = feature_select(
    complete_consensus_df,
    operation=feature_ops,
    na_cutoff=0
)

print(consensus_feature_select_df.shape)
consensus_feature_select_df.head()

# Split metadata and CP Features  
# The training data has Image_ features, while LINCS data has Cells_, Nuclei_, Cytoplasm_ features

# Get metadata features
meta_features = [c for c in complete_consensus_df.columns if c.startswith("Metadata_")]

# Get training data features (non-metadata columns)
training_features = [c for c in x_test_df.columns if not c.startswith("Metadata_") and c != "level_0"]

# Get consensus features after feature selection
consensus_features = [c for c in consensus_feature_select_df.columns if not c.startswith("Metadata_")]

print(f"Training features: {len(training_features)}")
print(f"Consensus features after selection: {len(consensus_features)}")

# CRITICAL FIX: Find overlapping features between training and consensus data
overlapping_features = [c for c in training_features if c in consensus_feature_select_df.columns]
print(f"Overlapping features: {len(overlapping_features)}")

# Use overlapping features if available, otherwise use all consensus features with warning
if len(overlapping_features) > 10:  # Reasonable threshold
    print(f"Using {len(overlapping_features)} overlapping features")
    feature_df = consensus_feature_select_df.loc[:, overlapping_features]
else:
    print(f"WARNING: Only {len(overlapping_features)} overlapping features found.")
    print("Using all consensus features - models may not work properly!")
    feature_df = consensus_feature_select_df.loc[:, consensus_features]

metadata_df = complete_consensus_df.loc[:, meta_features]

print(f"Final feature matrix shape: {feature_df.shape}")
print("Feature preview:")
feature_df.head()

# %%
# Split metadata and CP Features  
# The training data has Image_ features, while LINCS data has Cells_, Nuclei_, Cytoplasm_ features

# Get metadata features
meta_features = [c for c in complete_consensus_df.columns if c.startswith('Metadata_')]

# Get training data features (non-metadata columns)
training_features = [c for c in x_test_df.columns if not c.startswith('Metadata_') and c != 'level_0']

# Get consensus features after feature selection
consensus_features = [c for c in consensus_feature_select_df.columns if not c.startswith('Metadata_')]

print(f"Training features: {len(training_features)}")
print(f"Consensus features after selection: {len(consensus_features)}")

# CRITICAL FIX: Find overlapping features between training and consensus data
overlapping_features = [c for c in training_features if c in consensus_feature_select_df.columns]
print(f"Overlapping features: {len(overlapping_features)}")

# Use overlapping features if available, otherwise use all consensus features with warning
if len(overlapping_features) > 10:  # Reasonable threshold
    print(f"Using {len(overlapping_features)} overlapping features")
    feature_df = consensus_feature_select_df.loc[:, overlapping_features]
else:
    print(f"WARNING: Only {len(overlapping_features)} overlapping features found.")
    print("Using all consensus features - models may not work properly!")
    feature_df = consensus_feature_select_df.loc[:, consensus_features]

metadata_df = complete_consensus_df.loc[:, meta_features]

print(f"Final feature matrix shape: {feature_df.shape}")
print("Feature preview:")
feature_df.head()

# %% [markdown]
# ## 3) Apply all Regression Models to all Repurposing Plates

# %%
cell_health_features = list(model_dict.keys())

all_scores = {}
for cell_health_feature in cell_health_features:
    model_clf = model_dict[cell_health_feature]
    pred_df = model_clf.predict(feature_df)
    all_scores[cell_health_feature] = pred_df

# %% [markdown]
# ## 4) Output Results

# %%
# Output scores
all_score_df = pd.DataFrame.from_dict(all_scores)
repurp_predict_df = (
    metadata_df
    .merge(
        all_score_df,
        left_index=True,
        right_index=True
    )
    .query("Metadata_Plate_Map_Name != @filter_platemap")
)

output_real_file = os.path.join(
    output_dir,
    "repurposing_transformed_real_models_{}.tsv.gz".format(consensus)
)
repurp_predict_df.to_csv(output_real_file, sep="\t", index=False, compression="gzip")

print(repurp_predict_df.shape)
repurp_predict_df.head()
# Out:
# (10368, 75)
#   Metadata_Plate_Map_Name   Metadata_broad_sample Metadata_pert_well  \
# 0       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B13
# 1       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B14
# 2       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B15
# 3       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B16
# 4       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B17
#
#    Metadata_mmoles_per_liter  Metadata_dose_recode  \
# 0                   10.00000                     6
# 1                    3.33330                     5
# 2                    1.11110                     4
# 3                    0.37037                     3
# 4                    0.12346                     2
#
#    cell_health_modz_target_cc_late_mitosis_n_spots_h2ax_per_nucleus_area_mean  \
# 0                                           0.121840
# 1                                           0.135517
# 2                                           0.181414
# 3                                           0.168418
# 4                                           0.195843
#
#    cell_health_modz_target_cc_all_nucleus_roundness_mean  \
# 0                                           0.287876
# 1                                          -0.016983
# 2                                           0.029788
# 3                                           0.318820
# 4                                          -0.316581
#
#    cell_health_modz_target_cc_polyploid_n_objects  \
# 0                                        0.332128
# 1                                        0.175805
# 2                                        0.205290
# 3                                        0.194175
# 4                                        0.130700
#
#    cell_health_modz_target_cc_g1_n_objects  \
# 0                                 0.031668
# 1                                 0.045467
# 2                                 0.009674
# 3                                 0.241066
# 4                                 0.298723
#
#    cell_health_modz_target_cc_mitosis_n_objects  ...  \
# 0                                      0.293513  ...
# 1                                      0.271201  ...
# 2                                      0.302538  ...
# 3                                      0.359096  ...
# 4                                      0.185056  ...
#
#    cell_health_modz_target_cc_s_intensity_nucleus_area_mean  \
# 0                                          -0.041590
# 1                                          -0.615482
# 2                                          -0.577316
# 3                                          -0.407993
# 4                                          -0.114774
#
#    cell_health_modz_target_cc_g2_high_h2ax  \
# 0                                 0.275196
# 1                                 0.516950
# 2                                 0.401250
# 3                                 0.307553
# 4                                 0.343276
#
#    cell_health_modz_target_cc_late_mitosis_n_spots_h2ax_mean  \
# 0                                           0.231984
# 1                                           0.242159
# 2                                           0.268255
# 3                                           0.248019
# 4                                           0.234374
#
#    cell_health_modz_target_cc_cc_high_h2ax  \
# 0                                 0.034737
# 1                                 0.012577
# 2                                 0.080886
# 3                                 0.047578
# 4                                 0.226134
#
#    cell_health_modz_target_vb_percent_dead_only  \
# 0                                      0.226777
# 1                                      0.632890
# 2                                      0.207432
# 3                                      0.253732
# 4                                      0.262437
#
#    cell_health_modz_target_cc_s_high_h2ax  \
# 0                                0.237375
# 1                                0.399858
# 2                                0.337209
# 3                                0.344834
# 4                                0.247767
#
#    cell_health_modz_target_cc_cc_n_spots_h2ax_per_nucleus_area_mean  \
# 0                                           0.105485
# 1                                           0.022915
# 2                                           0.180617
# 3                                           0.138011
# 4                                           0.298132
#
#    cell_health_modz_target_cc_s_n_spots_h2ax_per_nucleus_area_mean  \
# 0                                           0.153677
# 1                                           0.202797
# 2                                           0.285974
# 3                                           0.306638
# 4                                           0.395778
#
#    cell_health_modz_target_cc_g1_plus_g2_count  \
# 0                                    -0.530986
# 1                                    -0.159769
# 2                                    -0.254186
# 3                                    -0.314815
# 4                                     0.186500
#
#    cell_health_modz_target_vb_live_cell_width_length
# 0                                           0.144455
# 1                                          -0.294545
# 2                                          -0.048311
# 3                                           0.038360
# 4                                          -0.051261
#
# [5 rows x 75 columns]

# %% [markdown]
# ## 5) Apply UMAP
#
# ### Part 1: Apply UMAP to Cell Health Transformed Repurposing Hub Features

# %%
reducer = umap.UMAP(random_state=1234, n_components=2)

predict_embedding_df = pd.DataFrame(
    reducer.fit_transform(repurp_predict_df.loc[:, cell_health_features]),
    columns=["umap_x", "umap_y"]
)

predict_embedding_df = (
    metadata_df
    .merge(
        predict_embedding_df,
        left_index=True,
        right_index=True
    )
    .query("Metadata_Plate_Map_Name != @filter_platemap")
)

output_real_file = os.path.join(
    output_dir,
    "repurposing_umap_transformed_real_models_{}.tsv.gz".format(consensus)
)

predict_embedding_df.to_csv(output_real_file, sep="\t", index=False, compression="gzip")

print(predict_embedding_df.shape)
predict_embedding_df.head()
# Out:
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py:439: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "make_euclidean_tree" failed type inference due to: Cannot unify RandomProjectionTreeNode(array(int64, 1d, C), bool, none, none, none, none) and RandomProjectionTreeNode(none, bool, array(float32, 1d, C), float64, RandomProjectionTreeNode(array(int64, 1d, C), bool, none, none, none, none), RandomProjectionTreeNode(array(int64, 1d, C), bool, none, none, none, none)) for '$14.16', defined at /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py (446)
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py", line 446:
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
#     <source elided>
#
#         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#         ^
#
# [1] During: resolving callee type: recursive(type(CPUDispatcher(<function make_euclidean_tree at 0x11c935048>)))
# [2] During: typing of call at /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py (446)
#
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py", line 446:
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
#     <source elided>
#
#         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#         ^
#
#   @numba.jit()
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/numba/compiler.py:742: NumbaWarning: Function "make_euclidean_tree" was compiled in object mode without forceobj=True.
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py", line 440:
# @numba.jit()
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
# ^
#
#   self.func_ir.loc))
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/numba/compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/rp_tree.py", line 440:
# @numba.jit()
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/nndescent.py:92: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/utils.py", line 407:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/numba/compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/umap_.py:328: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "fuzzy_simplicial_set" failed type inference due to: Untyped global name 'nearest_neighbors': cannot determine Numba type of <class 'function'>
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/umap_.py", line 446:
# def fuzzy_simplicial_set(
#     <source elided>
#     if knn_indices is None or knn_dists is None:
#         knn_indices, knn_dists, _ = nearest_neighbors(
#         ^
#
#   @numba.jit()
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/numba/compiler.py:742: NumbaWarning: Function "fuzzy_simplicial_set" was compiled in object mode without forceobj=True.
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/umap_.py", line 329:
# @numba.jit()
# def fuzzy_simplicial_set(
# ^
#
#   self.func_ir.loc))
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/numba/compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/umap_.py", line 329:
# @numba.jit()
# def fuzzy_simplicial_set(
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# (9984, 7)
#   Metadata_Plate_Map_Name   Metadata_broad_sample Metadata_pert_well  \
# 0       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B13
# 1       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B14
# 2       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B15
# 3       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B16
# 4       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B17
#
#    Metadata_mmoles_per_liter  Metadata_dose_recode    umap_x    umap_y
# 0                   10.00000                     6  2.767666 -0.822573
# 1                    3.33330                     5  1.135071 -3.082334
# 2                    1.11110                     4  2.384409 -2.227846
# 3                    0.37037                     3  2.249686 -1.413167
# 4                    0.12346                     2  2.428509 -1.821966

# %% [markdown]
# ### Part 2: Apply UMAP to All Repurposing Hub Cell Painting Profiles

# %%
reducer = umap.UMAP(random_state=1234, n_components=2)

repurp_embedding_df = pd.DataFrame(
    reducer.fit_transform(
        consensus_feature_select_df.loc[:, [c for c in consensus_feature_select_df.columns if not c.startswith("Metadata_") and c != "level_0"]]
    ),
    columns=["umap_x", "umap_y"]
)

repurp_embedding_df = (
    metadata_df
    .merge(
        repurp_embedding_df,
        left_index=True,
        right_index=True
    )
    .query("Metadata_Plate_Map_Name != @filter_platemap")
)

output_real_file = os.path.join(
    output_dir,
    "repurposing_umap_transformed_cell_painting_{}.tsv.gz".format(consensus)
)
repurp_embedding_df.to_csv(output_real_file, sep="\t", index=False, compression="gzip")

print(repurp_embedding_df.shape)
repurp_embedding_df.head()
# Out:
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/numba/compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../miniconda3/envs/cell-health/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# (10368, 7)
#   Metadata_Plate_Map_Name   Metadata_broad_sample Metadata_pert_well  \
# 0       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B13
# 1       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B14
# 2       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B15
# 3       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B16
# 4       C-7161-01-LM6-001  BRD-A25234499-001-18-3                B17
#
#    Metadata_mmoles_per_liter  Metadata_dose_recode    umap_x    umap_y
# 0                   10.00000                     6 -1.580029 -0.921932
# 1                    3.33330                     5 -1.904766 -2.436100
# 2                    1.11110                     4 -1.899164 -2.591488
# 3                    0.37037                     3 -1.708769 -0.886060
# 4                    0.12346                     2 -1.857128 -2.708612

# %% [markdown]
# ## Merge Data Together for Shiny App Exploration

# %%
# Load MOA file
moa_url = "https://raw.githubusercontent.com/broadinstitute/lincs-cell-painting/"
moa_url = f"{moa_url}/{commit_hash}/metadata/moa/repurposing_info_external_moa_map_resolved.tsv"

moa_df = pd.read_csv(moa_url, sep="\t")

print(moa_df.shape)
moa_df.head(3)
# Out:
# (1570, 10)
#              broad_sample       broad_id     pert_iname      InChIKey14  \
# 0  BRD-A00147595-001-01-5  BRD-A00147595  balaglitazone  IETKPTYAGKZLKY
# 1  BRD-A00218260-001-03-4  BRD-A00218260   flutrimazole  QHMWCHQXCUNUAK
# 2  BRD-A00376169-001-01-6  BRD-A00376169            KBG  FOLRUCXBTYDAQK
#
#                                                 moa target         broad_date  \
# 0  insulin sensitizer|PPAR receptor partial agonist  PPARG  broad_id_20170327
# 1                      sterol demethylase inhibitor    NaN  broad_id_20170327
# 2                              neprilysin inhibitor    MME  broad_id_20170327
#
#   clinical_phase alternative_moa alternative_target
# 0        Phase 3             NaN                NaN
# 1       Launched             NaN                NaN
# 2        Phase 2             NaN                NaN

# %%
core_id = [
    "{}-{}".format(
        x.split("-")[0],
        x.split("-")[1]
    ) if x != "DMSO"
    else x
    for x in repurp_embedding_df.Metadata_broad_sample
]

repurp_embedding_with_pert_df = (
    repurp_embedding_df
    .assign(Metadata_broad_core_id=core_id)
    .sort_index(axis="columns")
    .merge(
        moa_df,
        left_on="Metadata_broad_core_id",
        right_on="broad_id",
        how="left"
    )
)

print(repurp_embedding_with_pert_df.shape)
repurp_embedding_with_pert_df.head()
# Out:
# (10368, 18)
#   Metadata_Plate_Map_Name Metadata_broad_core_id   Metadata_broad_sample  \
# 0       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 1       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 2       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 3       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 4       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
#
#    Metadata_dose_recode  Metadata_mmoles_per_liter Metadata_pert_well  \
# 0                     6                   10.00000                B13
# 1                     5                    3.33330                B14
# 2                     4                    1.11110                B15
# 3                     3                    0.37037                B16
# 4                     2                    0.12346                B17
#
#      umap_x    umap_y            broad_sample       broad_id  \
# 0 -1.580029 -0.921932  BRD-A25234499-001-18-3  BRD-A25234499
# 1 -1.904766 -2.436100  BRD-A25234499-001-18-3  BRD-A25234499
# 2 -1.899164 -2.591488  BRD-A25234499-001-18-3  BRD-A25234499
# 3 -1.708769 -0.886060  BRD-A25234499-001-18-3  BRD-A25234499
# 4 -1.857128 -2.708612  BRD-A25234499-001-18-3  BRD-A25234499
#
#           pert_iname      InChIKey14                                 moa  \
# 0  aminoglutethimide  ROBVIMPUHSLWNV  glucocorticoid receptor antagonist
# 1  aminoglutethimide  ROBVIMPUHSLWNV  glucocorticoid receptor antagonist
# 2  aminoglutethimide  ROBVIMPUHSLWNV  glucocorticoid receptor antagonist
# 3  aminoglutethimide  ROBVIMPUHSLWNV  glucocorticoid receptor antagonist
# 4  aminoglutethimide  ROBVIMPUHSLWNV  glucocorticoid receptor antagonist
#
#             target         broad_date clinical_phase alternative_moa  \
# 0  CYP11A1|CYP19A1  broad_id_20170327       Launched             NaN
# 1  CYP11A1|CYP19A1  broad_id_20170327       Launched             NaN
# 2  CYP11A1|CYP19A1  broad_id_20170327       Launched             NaN
# 3  CYP11A1|CYP19A1  broad_id_20170327       Launched             NaN
# 4  CYP11A1|CYP19A1  broad_id_20170327       Launched             NaN
#
#   alternative_target
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
shiny_merge_cols = [
    "Metadata_Plate_Map_Name",
    "Metadata_broad_sample",
    "Metadata_dose_recode",
    "Metadata_mmoles_per_liter",
    "Metadata_pert_well"
]

shiny_df = (
    repurp_embedding_with_pert_df.merge(
        repurp_predict_df,
        left_on=shiny_merge_cols,
        right_on=shiny_merge_cols,
        how="inner"
    )
    .drop(["broad_sample"], axis="columns")
    .query("Metadata_Plate_Map_Name != @filter_platemap")
)

print(shiny_df.shape)
shiny_df.head()
# Out:
# (10368, 87)
#   Metadata_Plate_Map_Name Metadata_broad_core_id   Metadata_broad_sample  \
# 0       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 1       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 2       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 3       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
# 4       C-7161-01-LM6-001          BRD-A25234499  BRD-A25234499-001-18-3
#
#    Metadata_dose_recode  Metadata_mmoles_per_liter Metadata_pert_well  \
# 0                     6                   10.00000                B13
# 1                     5                    3.33330                B14
# 2                     4                    1.11110                B15
# 3                     3                    0.37037                B16
# 4                     2                    0.12346                B17
#
#      umap_x    umap_y       broad_id         pert_iname  ...  \
# 0 -1.580029 -0.921932  BRD-A25234499  aminoglutethimide  ...
# 1 -1.904766 -2.436100  BRD-A25234499  aminoglutethimide  ...
# 2 -1.899164 -2.591488  BRD-A25234499  aminoglutethimide  ...
# 3 -1.708769 -0.886060  BRD-A25234499  aminoglutethimide  ...
# 4 -1.857128 -2.708612  BRD-A25234499  aminoglutethimide  ...
#
#   cell_health_modz_target_cc_s_intensity_nucleus_area_mean  \
# 0                                          -0.041590
# 1                                          -0.615482
# 2                                          -0.577316
# 3                                          -0.407993
# 4                                          -0.114774
#
#   cell_health_modz_target_cc_g2_high_h2ax  \
# 0                                0.275196
# 1                                0.516950
# 2                                0.401250
# 3                                0.307553
# 4                                0.343276
#
#   cell_health_modz_target_cc_late_mitosis_n_spots_h2ax_mean  \
# 0                                           0.231984
# 1                                           0.242159
# 2                                           0.268255
# 3                                           0.248019
# 4                                           0.234374
#
#   cell_health_modz_target_cc_cc_high_h2ax  \
# 0                                0.034737
# 1                                0.012577
# 2                                0.080886
# 3                                0.047578
# 4                                0.226134
#
#   cell_health_modz_target_vb_percent_dead_only  \
# 0                                     0.226777
# 1                                     0.632890
# 2                                     0.207432
# 3                                     0.253732
# 4                                     0.262437
#
#   cell_health_modz_target_cc_s_high_h2ax  \
# 0                               0.237375
# 1                               0.399858
# 2                               0.337209
# 3                               0.344834
# 4                               0.247767
#
#   cell_health_modz_target_cc_cc_n_spots_h2ax_per_nucleus_area_mean  \
# 0                                           0.105485
# 1                                           0.022915
# 2                                           0.180617
# 3                                           0.138011
# 4                                           0.298132
#
#    cell_health_modz_target_cc_s_n_spots_h2ax_per_nucleus_area_mean  \
# 0                                           0.153677
# 1                                           0.202797
# 2                                           0.285974
# 3                                           0.306638
# 4                                           0.395778
#
#    cell_health_modz_target_cc_g1_plus_g2_count  \
# 0                                    -0.530986
# 1                                    -0.159769
# 2                                    -0.254186
# 3                                    -0.314815
# 4                                     0.186500
#
#    cell_health_modz_target_vb_live_cell_width_length
# 0                                           0.144455
# 1                                          -0.294545
# 2                                          -0.048311
# 3                                           0.038360
# 4                                          -0.051261
#
# [5 rows x 87 columns]

# %%
shiny_file = os.path.join(
    "repurposing_cellhealth_shiny",
    "data",
    "moa_cell_health_{}.tsv.gz".format(consensus)
)

shiny_df.to_csv(shiny_file, sep='\t', index=False, compression="gzip")

# %%
# Merge with transformed data compatibility
# Use metadata columns for merging since feature structure has changed
metadata_cols = [c for c in complete_consensus_df.columns if c.startswith('Metadata_')]
shiny_combined_df = shiny_df.merge(
    complete_consensus_df[metadata_cols + ['level_0']],  # Include level_0 for compatibility
    on=metadata_cols,
    how="inner"
)

# %% [markdown]
# ## Output Correlation Matrix

# %%
shiny_features = [c for c in consensus_feature_select_df.columns if not c.startswith("Metadata_") and c != "level_0"]
cell_health_features = [x for x in shiny_df if x.startswith("cell_health")]

# %%
all_results = []
for cell_health_feature in cell_health_features:
    cell_health = shiny_combined_df.loc[:, cell_health_feature]
    for cp_feature in shiny_features:
        feature = shiny_combined_df.loc[:, cp_feature]
        cor_result, pval = scipy.stats.pearsonr(cell_health, feature)
        all_results.append([cell_health_feature, cp_feature, cor_result, pval])
# Out:
# /Users/gway/miniconda3/envs/cell-health/lib/python3.7/site-packages/scipy/stats/stats.py:3399: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
# Output correlation matrix for cell health predictions and CellProfiler features
cor_results_df = (
    pd.DataFrame(
        np.array(all_results), columns=["cell_health", "cp_feature", "pearson_cor", "pval"]
    )
    .sort_values(by="pearson_cor", ascending=False)
    .reset_index(drop=True)
)

cor_results_df.pearson_cor = cor_results_df.pearson_cor.astype(float)

cor_results_df = (
    cor_results_df
    .pivot_table(columns=["cell_health"], index=["cp_feature"], values="pearson_cor")
)

print(cor_results_df.shape)
cor_results_df.head(3)
# Out:
# (567, 68)
# cell_health                  cell_health_modz_target_cc_all_high_h2ax  \
# cp_feature
# Cells_AreaShape_FormFactor                                  -0.675377
# Cells_AreaShape_Orientation                                  0.109455
# Cells_AreaShape_Zernike_2_2                                  0.032624
#
# cell_health                  cell_health_modz_target_cc_all_large_notround_polynuclear_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                           -0.461193
# Cells_AreaShape_Orientation                                           0.249087
# Cells_AreaShape_Zernike_2_2                                           0.459940
#
# cell_health                  cell_health_modz_target_cc_all_large_round_polyploid_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                           -0.433846
# Cells_AreaShape_Orientation                                           0.312104
# Cells_AreaShape_Zernike_2_2                                           0.456030
#
# cell_health                  cell_health_modz_target_cc_all_n_objects  \
# cp_feature
# Cells_AreaShape_FormFactor                                   0.093190
# Cells_AreaShape_Orientation                                  0.279330
# Cells_AreaShape_Zernike_2_2                                  0.686729
#
# cell_health                  cell_health_modz_target_cc_all_n_spots_h2ax_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                          -0.609459
# Cells_AreaShape_Orientation                                          0.325335
# Cells_AreaShape_Zernike_2_2                                          0.425207
#
# cell_health                  cell_health_modz_target_cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                           -0.517603
# Cells_AreaShape_Orientation                                           0.330253
# Cells_AreaShape_Zernike_2_2                                           0.496030
#
# cell_health                  cell_health_modz_target_cc_all_nucleus_area_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                          -0.201257
# Cells_AreaShape_Orientation                                         -0.179699
# Cells_AreaShape_Zernike_2_2                                         -0.569525
#
# cell_health                  cell_health_modz_target_cc_all_nucleus_roundness_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                           -0.251131
# Cells_AreaShape_Orientation                                           0.309541
# Cells_AreaShape_Zernike_2_2                                           0.588909
#
# cell_health                  cell_health_modz_target_cc_cc_early_mitosis  \
# cp_feature
# Cells_AreaShape_FormFactor                                      0.174370
# Cells_AreaShape_Orientation                                    -0.276428
# Cells_AreaShape_Zernike_2_2                                    -0.558868
#
# cell_health                  cell_health_modz_target_cc_cc_g1  ...  \
# cp_feature                                                     ...
# Cells_AreaShape_FormFactor                           0.006384  ...
# Cells_AreaShape_Orientation                         -0.270623  ...
# Cells_AreaShape_Zernike_2_2                         -0.603441  ...
#
# cell_health                  cell_health_modz_target_vb_num_live_cells  \
# cp_feature
# Cells_AreaShape_FormFactor                                    0.160444
# Cells_AreaShape_Orientation                                   0.257589
# Cells_AreaShape_Zernike_2_2                                   0.670240
#
# cell_health                  cell_health_modz_target_vb_percent_all_apoptosis  \
# cp_feature
# Cells_AreaShape_FormFactor                                           0.362358
# Cells_AreaShape_Orientation                                         -0.358588
# Cells_AreaShape_Zernike_2_2                                         -0.617549
#
# cell_health                  cell_health_modz_target_vb_percent_caspase_dead_only  \
# cp_feature
# Cells_AreaShape_FormFactor                                            0.550042
# Cells_AreaShape_Orientation                                          -0.333667
# Cells_AreaShape_Zernike_2_2                                          -0.513345
#
# cell_health                  cell_health_modz_target_vb_percent_dead  \
# cp_feature
# Cells_AreaShape_FormFactor                                  0.303673
# Cells_AreaShape_Orientation                                -0.359261
# Cells_AreaShape_Zernike_2_2                                -0.642031
#
# cell_health                  cell_health_modz_target_vb_percent_dead_only  \
# cp_feature
# Cells_AreaShape_FormFactor                                       0.154904
# Cells_AreaShape_Orientation                                     -0.324598
# Cells_AreaShape_Zernike_2_2                                     -0.680564
#
# cell_health                  cell_health_modz_target_vb_percent_early_apoptosis  \
# cp_feature
# Cells_AreaShape_FormFactor                                            0.110851
# Cells_AreaShape_Orientation                                          -0.311398
# Cells_AreaShape_Zernike_2_2                                          -0.657186
#
# cell_health                  cell_health_modz_target_vb_percent_late_apoptosis  \
# cp_feature
# Cells_AreaShape_FormFactor                                            0.369370
# Cells_AreaShape_Orientation                                          -0.367548
# Cells_AreaShape_Zernike_2_2                                          -0.620867
#
# cell_health                  cell_health_modz_target_vb_percent_live  \
# cp_feature
# Cells_AreaShape_FormFactor                                 -0.303552
# Cells_AreaShape_Orientation                                 0.359340
# Cells_AreaShape_Zernike_2_2                                 0.642168
#
# cell_health                  cell_health_modz_target_vb_ros_back_mean  \
# cp_feature
# Cells_AreaShape_FormFactor                                   0.478296
# Cells_AreaShape_Orientation                                 -0.365048
# Cells_AreaShape_Zernike_2_2                                 -0.536552
#
# cell_health                  cell_health_modz_target_vb_ros_mean
# cp_feature
# Cells_AreaShape_FormFactor                              0.425893
# Cells_AreaShape_Orientation                            -0.357670
# Cells_AreaShape_Zernike_2_2                            -0.571678
#
# [3 rows x 68 columns]
